# %%
import MuMoT as mmt
# Out:
# Created `%%model` as an alias for `%%latex`.

# %%
# %%model
# $
# U -> A : g_1
# U -> B : g_2
# A -> U : a_1
# B -> U : a_2
# A + U -> A + A : r_1
# B + U -> B + B : r_2
# A + B -> A + U : s
# A + B -> B + U : s
# $
# Out:
# $
# U -> A : g_1
# U -> B : g_2
# A -> U : a_1
# B -> U : a_2
# A + U -> A + A : r_1
# B + U -> B + B : r_2
# A + B -> A + U : s
# A + B -> B + U : s
# $

# %%
model1 = mmt.parseModel(In[2])

# %%
model2 = model1.substitute('a_1 = 1/v_1, a_2 = 1/v_2, g_1 = v_1, g_2 = v_2, r_1 = v_1, r_2 = v_2')

# %%
model3 = model2.substitute('v_1 = \\Delta + \\mu/2, v_2 = \\Delta - \\mu/2')

# %%
model3.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}A}{\textrm{d}t} := - A B s + A U \left(\Delta + \frac{\mu}{2}\right) - \frac{A}{\Delta + \frac{\mu}{2}} + U \left(\Delta + \frac{\mu}{2}\right)$$
# $$\displaystyle \frac{\textrm{d}B}{\textrm{d}t} := - A B s + B U \left(\Delta - \frac{\mu}{2}\right) - \frac{B}{\Delta - \frac{\mu}{2}} + U \left(\Delta - \frac{\mu}{2}\right)$$
# $$\displaystyle \frac{\textrm{d}U}{\textrm{d}t} := 2 A B s - A U \left(\Delta + \frac{\mu}{2}\right) + \frac{A}{\Delta + \frac{\mu}{2}} - B U \left(\Delta - \frac{\mu}{2}\right) + \frac{B}{\Delta - \frac{\mu}{2}} - U \left(\Delta - \frac{\mu}{2}\right) - U \left(\Delta + \frac{\mu}{2}\right)$$

# %%
model4 = model3.substitute('U = N - \A - \B')

# %%
model4.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}A}{\textrm{d}t} := - A B s + A \left(- B + - A + N\right) \left(\Delta + \frac{\mu}{2}\right) - \frac{A}{\Delta + \frac{\mu}{2}} + \left(- B + - A + N\right) \left(\Delta + \frac{\mu}{2}\right)$$
# $$\displaystyle \frac{\textrm{d}B}{\textrm{d}t} := - A B s + B \left(- B + - A + N\right) \left(\Delta - \frac{\mu}{2}\right) - \frac{B}{\Delta - \frac{\mu}{2}} + \left(- B + - A + N\right) \left(\Delta - \frac{\mu}{2}\right)$$

# %%
model4.bifurcation('s','A')
# Out:
# <img src="data:image/png;base64,..." width="640">
