# %% [markdown]
# # Ant recruitment model

# %%
import MuMoT.MuMoT as mmt
# Out:
# Created `%%model` as an alias for `%%latex`.

# %%
# %%model
# U -> A : d_A
# U -> B : d_B
# A -> U : a_A
# B -> U : a_B
# A + U -> A + A : r_A
# B + U -> B + B : r_B
# A + B -> A + A : s_A
# A + B -> B + B : s_B
# Out:
# U -> A : d_A
# U -> B : d_B
# A -> U : a_A
# B -> U : a_B
# A + U -> A + A : r_A
# B + U -> B + B : r_B
# A + B -> A + A : s_A
# A + B -> B + B : s_B

# %%
model1 = mmt.parseModel(In[2])

# %%
model2 = model1.substitute('U = N - A - B')

# %%
model3 = model2.substitute('d_A = d * v_A, d_B = d * v_B, a_A = a / v_A, a_B = a / v_B, r_A = r * v_A, r_B = r * v_B, s_A = s * v_A, s_B = s * v_B')

# %%
model4 = model3.substitute('v_A = (V+\\Delta)/2, v_B = (V-\\Delta)/2')

# %%
model4.show()
# Out:
# $$U  \xrightarrow{\frac{d}{2} \left(\Delta + V\right)}A $$
# $$U  \xrightarrow{\frac{d}{2} \left(- \Delta + V\right)}B $$
# $$A  \xrightarrow{\frac{2 a}{\Delta + V}}U $$
# $$B  \xrightarrow{\frac{2 a}{- \Delta + V}}U $$
# $$A + U  \xrightarrow{\frac{r}{2} \left(\Delta + V\right)}A + A $$
# $$B + U  \xrightarrow{\frac{r}{2} \left(- \Delta + V\right)}B + B $$
# $$A + B  \xrightarrow{\frac{s}{2} \left(\Delta + V\right)}A + A $$
# $$A + B  \xrightarrow{\frac{s}{2} \left(- \Delta + V\right)}B + B $$

# %%
model4.stream('A','B',params=[('\\Delta',0.1)])
# Out:
# FloatSlider(value=0.5, description='\\(V\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(a\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(d\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(r\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(s\\)', max=10.0, readout_format='.1f')
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
model4.stream('A','B')
# Out:
# FloatSlider(value=0.5, description='\\(\\Delta\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(V\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(a\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(d\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(r\\)', max=10.0, readout_format='.1f')
# FloatSlider(value=0.5, description='\\(s\\)', max=10.0, readout_format='.1f')
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <div id='2a4a6477-22fa-4f04-9d1c-9ae862a7038f'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6f7e43592413> in <module>()
# ----> 1 model4.stream('A','B')
#
# ~/Google Drive/Home/Git/MuMoT/MuMoT/MuMoT.py in stream(self, stateVariable1, stateVariable2, stateVariable3, params, **kwargs)
#     825
#     826             # construct view
# --> 827             modelView = MuMoTstreamView(self, viewController, SOL_2ndOrdMomDict, stateVariable1, stateVariable2, stateVariable3, params = params, **kwargs)
#     828
#     829             viewController.setView(modelView)
#
# ~/Google Drive/Home/Git/MuMoT/MuMoT/MuMoT.py in __init__(self, model, controller, SOL_2ndOrd, stateVariable1, stateVariable2, stateVariable3, figure, params, **kwargs)
#    5897             self._checkConstReactants = None
#    5898         silent = kwargs.get('silent', False)
# -> 5899         super().__init__(model, controller, SOL_2ndOrd, stateVariable1, stateVariable2, stateVariable3, figure, params, **kwargs)
#    5900         self._generatingCommand = "stream"
#    5901
#
# ~/Google Drive/Home/Git/MuMoT/MuMoT/MuMoT.py in __init__(self, model, controller, SOL_2ndOrd, stateVariable1, stateVariable2, stateVariable3, figure, params, **kwargs)
#    4909
#    4910         if not(silent):
# -> 4911             self._plot_field()
#    4912
#    4913
#
# ~/Google Drive/Home/Git/MuMoT/MuMoT/MuMoT.py in _plot_field(self, _)
#    5919
#    5920             if self._speed is not None:
# -> 5921                 fig_stream=plt.streamplot(self._X, self._Y, self._Xdot, self._Ydot, color = self._speed, cmap = 'gray') ## @todo: define colormap by user keyword
#    5922             else:
#    5923                 fig_stream=plt.streamplot(self._X, self._Y, self._Xdot, self._Ydot, color = 'k') ## @todo: define colormap by user keyword
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/matplotlib/pyplot.py in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, hold, data)
#    3593                             arrowsize=arrowsize, arrowstyle=arrowstyle,
#    3594                             minlength=minlength, transform=transform,
# -> 3595                             zorder=zorder, start_points=start_points, data=data)
#    3596     finally:
#    3597         ax._hold = washold
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/matplotlib/axes/_axes.py in streamplot(self, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points)
#    4624                                               start_points=start_points,
#    4625                                               transform=transform,
# -> 4626                                               zorder=zorder)
#    4627         return stream_container
#    4628     streamplot.__doc__ = mstream.streamplot.__doc__
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/matplotlib/streamplot.py in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points)
#     196     lc.sticky_edges.y[:] = [grid.y_origin, grid.y_origin + grid.height]
#     197     if use_multicolor_lines:
# --> 198         lc.set_array(np.ma.hstack(line_colors))
#     199         lc.set_cmap(cmap)
#     200         lc.set_norm(norm)
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/numpy/ma/extras.py in __call__(self, x, *args, **params)
#     297     def __call__(self, x, *args, **params):
#     298         func = getattr(np, self.__name__)
# --> 299         _d = func(tuple([np.asarray(a) for a in x]), *args, **params)
#     300         _m = func(tuple([getmaskarray(a) for a in x]), *args, **params)
#     301         return masked_array(_d, mask=_m)
#
# //anaconda/envs/MumotEnv/lib/python3.5/site-packages/numpy/core/shape_base.py in hstack(tup)
#     291         return _nx.concatenate(arrs, 0)
#     292     else:
# --> 293         return _nx.concatenate(arrs, 1)
#     294
#     295
#
# ValueError: need at least one array to concatenate
