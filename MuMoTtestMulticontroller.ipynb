# %%
import MuMoT.MuMoT as mmt # if working directly from git clone
# Out:
# Created `%%model` as an alias for `%%latex`.

# %%
# %%model
# $
# U -> A : g_1
# U -> B : g_2
# A -> U : a_1
# B -> U : a_2
# A + U -> A + A : r_1
# B + U -> B + B : r_2
# A + B -> A + U : s
# A + B -> B + U : s
# $

# %%
model1 = mmt.parseModel(In[2])
model2 = model1.substitute('a_1 = 1/v_1, a_2 = 1/v_2, g_1 = v_1, g_2 = v_2, r_1 = v_1, r_2 = v_2')
model3 = model2.substitute('v_1 = \\mu + \\Delta/2, v_2 = \\mu - \\Delta/2')
model4 = model3.substitute('U = N - \A - \B')

# %%
# %%model
# $
# U -> A : g_1
# U -> B : g_2
# U -> C : g_3
# A -> U : a_1
# B -> U : a_2
# C -> U : a_3
# A + U -> A + A : r_1
# B + U -> B + B : r_2
# C + U -> C + C : r_3
# A + B -> A + U : s
# A + B -> B + U : s
# A + C -> A + U : s
# A + C -> C + U : s
# B + C -> B + U : s
# B + C -> C + U : s
# $

# %%
model7 = mmt.parseModel(In[4])
model8 = model7.substitute('U = N - A - B - C')
model9 = model8.substitute('a_1 = a, a_2 = a, a_3 = a, g_1 = g, g_2 = g, g_3 = g, r_1 = r, r_2 = r, r_3 = r')

# %%
multiController1 = mmt.MuMoTmultiController([model4.stream('A', 'B', silent = True, showFixedPoints=False), 
                                             model4.vector('A', 'B', silent = True, showFixedPoints=False)], shareAxes = True
                                            , params = [('\\Delta',0),('s',0)])

# %%
multiController1.showLogs()

# %%
bookmark = mmt.MuMoTmultiController([model4.stream('A', 'B', showFixedPoints = False, silent = True, bookmark = False), model4.vector('A', 'B', showFixedPoints = False, silent = True, bookmark = False)], params = [('\\mu', 0.5), ('\\Delta', 0), ('s', 0), ('plotLimits', 1), ('systemSize', 1)], shareAxes = True, bookmark = False)

# %%
multiController1._fixedParams

# %% [markdown]
# ## Target
#
# What value should subPlotNum take?

# %%
bookmark = mmt.MuMoTmultiController([model4.stream('A', 'B', silent = True, showFixedPoints = False, bookmark = False), model4.vector('A', 'B', silent = True, showFixedPoints = False, bookmark = False)], params = [('s', 0.5), ('plotLimits', 1), ('systemSize', 1)], shareAxes = True, bookmark = False)

# %%
multiController2 = mmt.MuMoTmultiController([model4.vector('A', 'B', silent = True, showFixedPoints=False), model4.stream('A', 'B',showFixedPoints=False, silent = True)])

# %%
multiController3 = mmt.MuMoTmultiController([model4.stream('A', 'B', silent = True), 
                                             model4.vector('A', 'B', silent = True)], shareAxes = True, silent = True)

# %%
multiController4 = mmt.MuMoTmultiController([model9.vector('A', 'B', 'C', silent = True, showFixedPoints=True), 
                                             multiController3])

# %% [markdown]
# ## Non-constant system size

# %%
# %%model
# $
# (A) + X -> X + X : \alpha
# X + Y -> Y + Y : \beta
# Y -> \emptyset : \gamma
# $
# Out:
# $
# (A) + X -> X + X : \alpha
# X + Y -> Y + Y : \beta
# Y -> \emptyset : \gamma
# $

# %%
model10 = mmt.parseModel(In[21])

# %%
multiController5 =  mmt.MuMoTmultiController([model10.stream('X','Y', silent = True, showFixedPoints = False), model10.vector('X','Y', silent = True, showFixedPoints = False)], shareAxes = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
multiController5.showLogs(tail = True)
# Out:
# Showing last 5 of 7 log entries:
# Starting 2d stream plot with parameters (A=0.5), (alpha=0.5), (beta=0.5), (gamma=0.5), at 2017-11-07 20:09:37.853239
# Starting 2d vector plot with parameters (A=0.5), (alpha=0.5), (beta=0.5), (gamma=0.5), at 2017-11-07 20:09:38.262640
# Starting 2d stream plot with parameters (A=0.5), (alpha=0.5), (beta=2.6), (gamma=0.5), at 2017-11-07 20:09:39.502497
# Starting 2d vector plot with parameters (A=0.5), (alpha=0.5), (beta=2.6), (gamma=0.5), at 2017-11-07 20:09:39.948841
# bookmark = mmt.MuMoTmultiController([<modelName>.stream('X', 'Y', showFixedPoints = False, silent = True, bookmark = False), <modelName>.vector('X', 'Y', showFixedPoints = False, silent = True, bookmark = False)], params = [('\\alpha', 0.5), ('\\beta', 2.6), ('A', 0.5), ('\\gamma', 0.5), ('plotLimits', 3.5), ('systemSize', 1)], shareAxes = True, bookmark = False)

# %%
bookmark = mmt.MuMoTmultiController([model10.stream('X', 'Y', showFixedPoints = False, silent = True, bookmark = False), model10.vector('X', 'Y', showFixedPoints = False, silent = True, bookmark = False)], params = [('\\gamma', 0.5), ('\\alpha', 0.5), ('\\beta', 1.9), ('A', 0.5), ('plotLimits', 2.0), ('systemSize', 1)], shareAxes = True, bookmark = False)
