# %%
import mumot

mumot.about()
# Out:
# Created `%%model` as an alias for `%%latex`.
# Multiscale Modelling Tool (MuMoT): Version 1.0.0
# Authors: James A. R. Marshall, Andreagiovanni Reina, Thomas Bose
# Documentation: https://mumot.readthedocs.io/

# %%
model1 = mumot.parseModel(r"""
U -> A : g_1
A -> U : a_1
A + U -> A + A : r_1
""")

# %%
model1.showODEs()
# Out:
# $\displaystyle \displaystyle \frac{\textrm{d}U}{\textrm{d}t} := - A U r_{1} + A a_{1} - U g_{1}$
# $\displaystyle \displaystyle \frac{\textrm{d}A}{\textrm{d}t} := A U r_{1} - A a_{1} + U g_{1}$

# %%
model2 = model1.substitute('U = N - A')

# %%
modelStreamPlot = model2.stream('A', showFixedPoints = True, showNoise = True)
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(a_{1}\\)', max=20.0, readout_format='.1f', sty…
# FloatSlider(value=2.0, continuous_update=False, description='\\(g_{1}\\)', max=20.0, readout_format='.1f', sty…
# FloatSlider(value=2.0, continuous_update=False, description='\\(r_{1}\\)', max=20.0, readout_format='.1f', sty…
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', ste…
# Accordion(children=(Box(children=(IntSlider(value=20, continuous_update=False, description='Number of runs:', …
# Box(children=(Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log'), Button(icon='save…
# HTML(value='')
# <img src="data:image/png;base64,..." width="799.5333333333333">
# None
