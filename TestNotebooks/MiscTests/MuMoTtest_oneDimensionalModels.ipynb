# %% [markdown]
# # This notebook demonstrates some functionality of MuMoT when working with one-dimensional systems.

# %%
import mumot

mumot.__version__
# Out:
# /home/will/.venvs/mumot_dev/lib/python3.6/site-packages/matplotlib/__init__.py:915: MatplotlibDeprecationWarning: nbagg.transparent is deprecated and ignored. Use figure.facecolor instead.
#   mplDeprecation)
# Created `%%model` as an alias for `%%latex`.
# '0.1.0-dev'

# %%
# %%model
# $
# \emptyset + \alpha_\beta -> \alpha_\beta + \alpha_\beta : r
# \alpha_\beta + \alpha_\beta + \alpha_\beta -> \emptyset + \emptyset + \emptyset : b
# $
# Out:
# $
# \emptyset + \alpha_\beta -> \alpha_\beta + \alpha_\beta : r
# \alpha_\beta + \alpha_\beta + \alpha_\beta -> \emptyset + \emptyset + \emptyset : b
# $

# %%
##########################################################################################
#####  This model corresponds to the normal form of a pitchfork bifurcation in 1D  #######
##########################################################################################
model1 = mumot.parseModel(In[2])

# %%
model1.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}\alpha_{\beta}}{\textrm{d}t} := - 3 \alpha_{\beta}^{3} b + \alpha_{\beta} r$$

# %%
model1.showMasterEquation()
# Out:
# $$\frac{\partial}{\partial t} P{\left (\alpha_{\beta},t \right )}:= r ( \operatorname{E_{op}}{\left (\alpha_{\beta},-1 \right )} - 1 ) \alpha_{\beta} P{\left (\alpha_{\beta},t \right )} + b ( \operatorname{E_{op}}{\left (\alpha_{\beta},3 \right )} - 1 ) \frac{\alpha_{\beta}}{\overline{V}^{2}} \left(\alpha_{\beta} - 2\right) \left(\alpha_{\beta} - 1\right) P{\left (\alpha_{\beta},t \right )}$$

# %%
model1.showVanKampenExpansion()
# Out:
# $$- \sqrt{\overline{V}} \frac{d}{d t} \Phi_{\alpha_{\beta}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{\partial}{\partial t} P{\left (\eta_{\alpha_{\beta}},t \right )} :=
# 3 \Phi_{\alpha_{\beta}}^{3} \sqrt{\overline{V}} b \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 b}{2} \Phi_{\alpha_{\beta}}^{3} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + 9 \Phi_{\alpha_{\beta}}^{2} b \eta_{\alpha_{\beta}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + 9 \Phi_{\alpha_{\beta}}^{2} b P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{27 \Phi_{\alpha_{\beta}}^{2} b}{2 \overline{V}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{27 \Phi_{\alpha_{\beta}}^{2} b \eta_{\alpha_{\beta}}}{2 \sqrt{\overline{V}}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{18 b}{\sqrt{\overline{V}}} \Phi_{\alpha_{\beta}}^{2} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} - \Phi_{\alpha_{\beta}} \sqrt{\overline{V}} r \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{\Phi_{\alpha_{\beta}} r}{2} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{27 \Phi_{\alpha_{\beta}} b \eta_{\alpha_{\beta}}^{2}}{2 \overline{V}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{36 \Phi_{\alpha_{\beta}}}{\overline{V}} b \eta_{\alpha_{\beta}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 \Phi_{\alpha_{\beta}}}{\overline{V}} b P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 \Phi_{\alpha_{\beta}}}{\overline{V}^{2}} b \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 \Phi_{\alpha_{\beta}}}{\sqrt{\overline{V}}} b \eta_{\alpha_{\beta}}^{2} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{18 \Phi_{\alpha_{\beta}}}{\sqrt{\overline{V}}} b \eta_{\alpha_{\beta}} P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{27 \Phi_{\alpha_{\beta}}}{\overline{V}^{\frac{3}{2}}} b \eta_{\alpha_{\beta}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{48 \Phi_{\alpha_{\beta}}}{\overline{V}^{\frac{3}{2}}} b \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} - \eta_{\alpha_{\beta}} r \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} - r P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{3 b}{\overline{V}} \eta_{\alpha_{\beta}}^{3} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 b}{\overline{V}} \eta_{\alpha_{\beta}}^{2} P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{27 b \eta_{\alpha_{\beta}}^{2}}{2 \overline{V}^{2}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{48 b}{\overline{V}^{2}} \eta_{\alpha_{\beta}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} - \frac{21 b}{\overline{V}^{2}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{\eta_{\alpha_{\beta}} r}{2 \sqrt{\overline{V}}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{r}{\sqrt{\overline{V}}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 b \eta_{\alpha_{\beta}}^{3}}{2 \overline{V}^{\frac{3}{2}}} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{18 b}{\overline{V}^{\frac{3}{2}}} \eta_{\alpha_{\beta}}^{2} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 b}{\overline{V}^{\frac{3}{2}}} \eta_{\alpha_{\beta}} P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{9 b} ...

# %%
model1.showFokkerPlanckEquation()
# Out:
# $$\frac{\partial}{\partial t} P{\left (\eta_{\alpha_{\beta}},t \right )} := \frac{9 b}{2} \Phi_{\alpha_{\beta}}^{3} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} + 9 \Phi_{\alpha_{\beta}}^{2} b \eta_{\alpha_{\beta}} \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} + 9 \Phi_{\alpha_{\beta}}^{2} b P{\left (\eta_{\alpha_{\beta}},t \right )} + \frac{\Phi_{\alpha_{\beta}} r}{2} \frac{\partial^{2}}{\partial \eta_{\alpha_{\beta}}^{2}}  P{\left (\eta_{\alpha_{\beta}},t \right )} - \eta_{\alpha_{\beta}} r \frac{\partial}{\partial \eta_{\alpha_{\beta}}} P{\left (\eta_{\alpha_{\beta}},t \right )} - r P{\left (\eta_{\alpha_{\beta}},t \right )}$$

# %%
model1.showODEs(method='vanKampen')
# Out:
# $$\frac{d}{d t} \Phi_{\alpha_{\beta}} := \Phi_{\alpha_{\beta}} \left(- 3 \Phi_{\alpha_{\beta}}^{2} b + r\right)$$

# %%
model1.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}\alpha_{\beta}}{\textrm{d}t} := - 3 \alpha_{\beta}^{3} b + \alpha_{\beta} r$$

# %%
model1.showNoiseEquations()
# Out:
# $$\displaystyle \frac{\textrm{d}\left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}\left. \vphantom{Dg}\right>}{\textrm{d}t} := \left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}\left. \vphantom{Dg}\right> \left(- 9 \Phi_{\alpha_{\beta}}^{2} b + r\right)$$
# $$\displaystyle \frac{\textrm{d}\left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}^{2}\left. \vphantom{Dg}\right>}{\textrm{d}t} := 9 \Phi_{\alpha_{\beta}}^{3} b + \Phi_{\alpha_{\beta}} r - 2 \left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}^{2}\left. \vphantom{Dg}\right> \left(9 \Phi_{\alpha_{\beta}}^{2} b - r\right)$$

# %%
model1.showNoiseSolutions()
# Out:
# Stationary solutions of first and second order moments of noise:
# $$\left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}\left. \vphantom{Dg}\right>(t \to \infty):= 0$$
# $$\left< \vphantom{Dg}\right.\eta_{\alpha_{\beta}}^{2}\left. \vphantom{Dg}\right>(t \to \infty) := \frac{\Phi_{\alpha_{\beta}} \left(9 \Phi_{\alpha_{\beta}}^{2} b + r\right)}{2 \left(9 \Phi_{\alpha_{\beta}}^{2} b - r\right)}$$

# %%
mint1 = model1.integrate(initWidgets={'maxTime': [10,1,50,1]})
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(b\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(r\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{\\alpha_{\\beta}}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=10.0, continuous_update=False, description='Simulation time:', max=50.0, min=1.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial')), Checkbox(value=False, description='Plot population proportions')), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
mint1.showLogs()
# Out:
# Starting numerical integration of ODE system with parameters (b=2.0), (r=2.0), (initalpha_{beta}=1.0), (maxTime=10.0), (conserved=False), at 2018-06-05 10:55:54.657889
# Last point on curve:
# $$\alpha_{\beta}(t =10.0) = 5.774$$

# %%
model1.noiseCorrelations(initWidgets={'maxTime': [10,1,50,1]})
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(b\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(r\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{\\alpha_{\\beta}}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=10.0, continuous_update=False, description='Simulation time:', max=50.0, min=1.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
bif1 = model1.bifurcation('r', r'\alpha_\beta')
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(b\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=2.0, continuous_update=False, description='Initial \\(r\\) : ', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial:')), FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{\\alpha_{\\beta}}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial'))), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
bif1.showLogs()
# Out:
# Starting bifurcation plot with parameters (b=2.0), (initBifParam=2.0), (initalpha_{beta}=1.0), (bifurcationParameter='r'), (conserved=False), at 2018-06-05 10:56:16.164958
# State variable is:  alphabeta .
# The bifurcation parameter chosen is:  r .
# 2 stable steady state(s) detected and continuated. Initial conditions for state variables specified on sliders in Advanced options tab were not used.
# Special Points on curve:
# No special points could be detected.

# %%
mc1 = mumot.MuMoTmultiController([model1.integrate(params=[('b',2)], choose_yrange=[0,1], silent=True),
                          model1.integrate(params=[('b',1)], choose_yrange=[0,1], silent=True)],
                         shareAxes = False, silent=False);
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(r\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.1f', step=1.0, style=SliderStyle(description_width='initial'))
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{\\alpha_{\\beta}}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=3.0, continuous_update=False, description='Simulation time:', max=10.0, readout_format='.1f', style=SliderStyle(description_width='initial')), Checkbox(value=True, description='Plot population proportions', disabled=True)), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# <img src="data:image/png;base64,..." width="900">

# %%
mc1.showLogs()
# Out:
# Starting numerical integration of ODE system with parameters (r=2.0), (initalpha_{beta}=1.0), (maxTime=3.0), (conserved=False), (b=2), at 2018-06-05 10:56:26.243419
# Last point on curve:
# $$\Phi_{\alpha_{\beta}}(t =3.0) = 0.577$$
# Starting numerical integration of ODE system with parameters (r=2.0), (initalpha_{beta}=1.0), (maxTime=3.0), (conserved=False), (b=1), at 2018-06-05 10:56:26.708439
# Last point on curve:
# $$\Phi_{\alpha_{\beta}}(t =3.0) = 0.816$$

# %%
mumot.MuMoTmultiController([model1.integrate(initWidgets={'maxTime':[10,5,50,1], 
                                               'initialState':{'\\alpha_\\beta': [0.3,0,1,0.01]}},
                                           conserved=False, silent=True),
                          model1.noiseCorrelations(initWidgets={'maxTime':[10,5,50,1], 
                                               'initialState':{'\\alpha_\\beta': [0.5,0,1,0.01]}},
                                           conserved=False, silent=True)], shareAxes = False)
# Out:
# WARNING! the initial value of reactant alpha_{beta} has been changed to 1
#
# WARNING! the initial value of reactant alpha_{beta} has been changed to 1
# FloatSlider(value=2.0, continuous_update=False, description='\\(b\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(r\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.1f', step=1.0, style=SliderStyle(description_width='initial'))
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{\\alpha_{\\beta}}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=10.0, continuous_update=False, description='Simulation time:', max=50.0, min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial')), Checkbox(value=True, description='Plot population proportions', disabled=True)), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# <img src="data:image/png;base64,..." width="900">

# %%
# %%model
# $
# (A) -> X : k
# X + X -> \emptyset + \emptyset : h
# $
# Out:
# $
# (A) -> X : k
# X + X -> \emptyset + \emptyset : h
# $

# %%
############################################################################################
#####  This model is from van Kampen's book (1985, pp. 254), where analytical results  #####
#####  are available for comparison (it works!).  ##########################################
############################################################################################
model2 = mumot.parseModel(In[20])

# %%
model2.show()
# Out:
# $$(A)  \xrightarrow{k}X $$
# $$X + X  \xrightarrow{h}\emptyset + \emptyset $$

# %%
model2.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}X}{\textrm{d}t} := A k - 2 X^{2} h$$

# %%
model2.showODEs(method='vanKampen')
# Out:
# $$\frac{d}{d t} \Phi_{X} := \Phi_{A} k - 2 \Phi_{X}^{2} h$$

# %%
model2.showMasterEquation()
# Out:
# $$\frac{\partial}{\partial t} P{\left (X,t \right )}:= \frac{A k}{\overline{V}} ( \operatorname{E_{op}}{\left (X,-1 \right )} - 1 ) \overline{V} P{\left (X,t \right )} + h ( \operatorname{E_{op}}{\left (X,2 \right )} - 1 ) \frac{X}{\overline{V}} \left(X - 1\right) P{\left (X,t \right )}$$

# %%
model3 = model2.substitute('h = v, k = m')

# %%
model3.showODEs()
# Out:
# $$\displaystyle \frac{\textrm{d}X}{\textrm{d}t} := A m - 2 X^{2} v$$

# %%
model3.showODEs(method='vanKampen')
# Out:
# $$\frac{d}{d t} \Phi_{X} := \Phi_{A} m - 2 \Phi_{X}^{2} v$$

# %%
model3.showNoiseEquations()
# Out:
# $$\displaystyle \frac{\textrm{d}\left< \vphantom{Dg}\right.\eta_{X}\left. \vphantom{Dg}\right>}{\textrm{d}t} := - 4 \Phi_{X} \left< \vphantom{Dg}\right.\eta_{X}\left. \vphantom{Dg}\right> v$$
# $$\displaystyle \frac{\textrm{d}\left< \vphantom{Dg}\right.\eta_{X}^{2}\left. \vphantom{Dg}\right>}{\textrm{d}t} := \Phi_{A} m + 4 \Phi_{X}^{2} v - 8 \Phi_{X} \left< \vphantom{Dg}\right.\eta_{X}^{2}\left. \vphantom{Dg}\right> v$$

# %%
model3.showNoiseSolutions()
# Out:
# Stationary solutions of first and second order moments of noise:
# $$\left< \vphantom{Dg}\right.\eta_{X}\left. \vphantom{Dg}\right>(t \to \infty):= 0$$
# $$\left< \vphantom{Dg}\right.\eta_{X}^{2}\left. \vphantom{Dg}\right>(t \to \infty) := \frac{\Phi_{A} m}{8 \Phi_{X} v} + \frac{\Phi_{X}}{2}$$

# %%
model2.integrate()
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(\\Phi_{A}\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(h\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(k\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{X}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=3.0, continuous_update=False, description='Simulation time:', max=10.0, readout_format='.1f', style=SliderStyle(description_width='initial')), Checkbox(value=False, description='Plot population proportions')), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
model3.integrate()
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(\\Phi_{A}\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(m\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(v\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{X}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=3.0, continuous_update=False, description='Simulation time:', max=10.0, readout_format='.1f', style=SliderStyle(description_width='initial')), Checkbox(value=False, description='Plot population proportions')), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
model3.showStoichiometry()
# Out:
# $$\left \{ Reaction 1 : \left \{ rate : m, \quad A : const, \quad X : \left [ 0, \quad 1\right ]\right \}, \quad Reaction 2 : \left \{ rate : v, \quad X : \left [ 2, \quad 0\right ]\right \}\right \}$$

# %%
model2.showStoichiometry()
# Out:
# $$\left \{ Reaction 1 : \left \{ rate : k, \quad A : const, \quad X : \left [ 0, \quad 1\right ]\right \}, \quad Reaction 2 : \left \{ rate : h, \quad X : \left [ 2, \quad 0\right ]\right \}\right \}$$

# %%
model2.noiseCorrelations()
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(\\Phi_{A}\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(h\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(k\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=10.0, continuous_update=False, description='System size', min=5.0, readout_format='.0f', step=1.0, style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{X}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial')), FloatSlider(value=3.0, continuous_update=False, description='Simulation time:', max=10.0, readout_format='.1f', style=SliderStyle(description_width='initial'))), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">

# %%
model3.bifurcation('A','X')
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='\\(m\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# FloatSlider(value=2.0, continuous_update=False, description='\\(v\\)', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial'))
# Accordion(children=(Box(children=(FloatSlider(value=2.0, continuous_update=False, description='Initial \\(A\\) : ', max=20.0, readout_format='.1f', style=SliderStyle(description_width='initial:')), FloatSlider(value=1.0, continuous_update=False, description='$\\Phi_{X}$ at t=0: ', max=1.0, step=0.01, style=SliderStyle(description_width='initial'))), layout=Layout(flex_flow='column')),), selected_index=None, _titles={'0': 'Advanced options'})
# Button(icon='bookmark', style=ButtonStyle(), tooltip='Paste bookmark to log')
# HTML(value='')
# <img src="data:image/png;base64,..." width="640">
